# %%
from fastNLP.embeddings import StaticEmbedding
from fastNLP import Vocabulary, BucketSampler, DataSetIter, SequentialSampler
from fastNLP import DataSet
from fastNLP.io.data_bundle import DataBundle
from nltk.tokenize import word_tokenize
from tqdm import tqdm

# %%
def load_data(path, keys):
    metadata = {}
    with open(path, 'r') as f:
        for line in f:
            line = line.split('+++$+++')
            line = [x.strip() for x in line]
            metadata[line[0]] = dict(zip(keys, line[1:]))
    return metadata

# %%
movie_titles = load_data('./data/cornell movie-dialogs corpus/movie_titles_metadata.txt', 
                         ['movie title', 'movie year', 'IMDB rating', 'no. IMDB votes', 'genres'])
movie_characters = load_data('./data/cornell movie-dialogs corpus/movie_characters_metadata.txt',
                            ['character name', 'movieID', 'movie title', 'gender', 'position in credits']) 
movie_lines = load_data('./data/cornell movie-dialogs corpus/movie_lines.txt',
                       ['characterID', 'movieID', 'character name', 'utterance'])

# %%
movie_lines['L12455']
# Out:
# {'characterID': 'u152',
#  'movieID': 'm10',
#  'character name': 'ROLFE',
#  'utterance': 'Get some sleep.'}

# %%
input_sent = []
output_sent = []
speakers = []
movies = []
with open('./data/cornell movie-dialogs corpus/movie_conversations.txt', 'r') as f:
    cnt = 0
    for line in f:
        line = line.split('+++$+++')
        line = [x.strip() for x in line]
        line[3] = line[3][1:-1].split(', ')
        raw_words = [movie_lines[x[1:-1]]['utterance'] for x in line[3]]
        words = [word_tokenize(x) for x in raw_words]
        w = False
        for x in words:
            if len(x) == 0: w = True
        if w: continue
        input_sent += words[:-1]
        output_sent += words[1:]
        speakers += [line[1], line[0]] * ((len(line[3]) - 1) // 2)
        if len(line[3]) % 2 == 0: speakers += [line[1]]
        movies += [line[2]] * (len(line[3]) - 1)
        cnt += 1
        if cnt == 2000: break
dataset = DataSet({'input_sent':input_sent, 'speakers':speakers, 'movies':movies, 'output_sent':output_sent})
dataset.apply_field(lambda x: len(x), field_name='input_sent', new_field_name='seq_len')
dataset.apply_field(lambda x: x + ['<EOS>'], field_name='output_sent', new_field_name='output_sent')
print(dataset)
# Out:
# +----------------+----------+--------+-----------------+---------+
# | input_sent     | speakers | movies | output_sent     | seq_len |
# +----------------+----------+--------+-----------------+---------+
# | ['Can', 'we... | u2       | m0     | ['Well', ','... | 25      |
# | ['Well', ',... | u0       | m0     | ['Not', 'the... | 17      |
# | ['Not', 'th... | u2       | m0     | ['Okay', '..... | 11      |
# | ['You', "'r... | u2       | m0     | ['Forget', '... | 17      |
# | ['No', ',',... | u2       | m0     | ['Cameron', ... | 18      |
# | ['Cameron',... | u0       | m0     | ['The', 'thi... | 2       |
# | ['The', 'th... | u2       | m0     | ['Seems', 'l... | 30      |
# | ['Why', '?'... | u2       | m0     | ['Unsolved',... | 2       |
# | ['Unsolved'... | u0       | m0     | ['That', "'s... | 28      |
# | ['Gosh', ',... | u2       | m0     | ['Let', 'me'... | 11      |
# | ["C'esc", '... | u2       | m0     | ['Right', '.... | 8       |
# | ['Right', '... | u0       | m0     | ['I', 'do', ... | 11      |
# | ['I', 'do',... | u2       | m0     | ['That', "'s... | 51      |
# | ['That', "'... | u0       | m0     | ['Forget', '... | 10      |
# | ['How', 'is... | u2       | m0     | ['Well', ','... | 12      |
# | ['There', '... | u2       | m0     | ['Where', '?... | 2       |
# | ['You', 'go... | u2       | m0     | ['I', 'count... | 7       |
# | ['You', 'ha... | u2       | m0     | ['You', "'re... | 8       |
# | ['How', 'do... | u2       | m0     | ['Eber', "'s... | 11      |
# | ['Sure', 'h... | u2       | m0     | ['I', 'reall... | 3       |
# | ['I', 'real... | u0       | m0     | ['I', "'m", ... | 21      |
# | ['She', "'s... | u2       | m0     | ['Lesbian', ... | 5       |
# | ['Lesbian',... | u0       | m0     | ['So', 'that... | 29      |
# | ['So', 'tha... | u2       | m0     | ['Who', 'kno... | 13      |
# | ['Hi', '.']... | u2       | m0     | ['Looks', 'l... | 2       |
# | ...            | ...      | ...    | ...             | ...     |
# +----------------+----------+--------+-----------------+---------+

# %%
dataset.set_input('input_sent', 'speakers', 'seq_len')
dataset.set_target('output_sent')
train, test = dataset.split(0.005)
train, dev = train.split(0.005)
train = train[:20]
data_bundle = DataBundle()
data_bundle.set_dataset(train, 'train')
data_bundle.set_dataset(dev, 'dev')
data_bundle.set_dataset(test, 'test')
print(data_bundle)
# Out:
# In total 3 datasets:
# 	train has 20 instances.
# 	dev has 24 instances.
# 	test has 24 instances.

# %%
vocab = Vocabulary(min_freq=1)
vocab.from_dataset(train, field_name=['input_sent', 'output_sent'], no_create_entry_dataset=[dev, test])
vocab.index_dataset(train, field_name=['input_sent', 'output_sent'])
vocab.index_dataset(dev, field_name=['input_sent', 'output_sent'])
vocab.index_dataset(test, field_name=['input_sent', 'output_sent'])
speaker_vocab = Vocabulary()
speaker_vocab.from_dataset(train, field_name='speakers', no_create_entry_dataset=[dev, test])
speaker_vocab.index_dataset(train, field_name='speakers')
speaker_vocab.index_dataset(dev, field_name='speakers')
speaker_vocab.index_dataset(test, field_name='speakers')
print(len(vocab))
print(len(speaker_vocab))
# Out:
# 726
# 51

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import time

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, embedding, hidden_dim=64, dropout=0.5):
        super().__init__()

        self.embedding_dim = 100
        self.vocab_size = vocab_size
        self.embedding = embedding
        self.gru = nn.GRU(self.embedding_dim, hidden_dim, num_layers=1, dropout=0)
        self.dropout = nn.Dropout(dropout)

    def forward(self, words, input_lengths):
        # (input) words : (batch_size, seq_len)
        words = words.permute(1, 0)
        # words : (seq_len, batch_size)
        
        sorted_seq_lens = list(sorted([(idx, seq_len.item()) for
                                       idx, seq_len in zip(range(input_lengths.size(0)), list(input_lengths))],
                                      key=lambda x: x[1], reverse=True))
        idx = torch.LongTensor([x[0] for x in sorted_seq_lens])
        seq_len = torch.LongTensor([x[1] for x in sorted_seq_lens])
        new_words = torch.index_select(words, 1, idx)
        
        embedded = self.dropout(self.embedding(new_words))
        # embedded : (seq_len, batch_size, embedding_dim)

        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, seq_len)
        output, hidden = self.gru(packed)
        # output: (seq_len, batch_size, hidden_dim)
        # hidden: (num_layers, batch_size, hidden_dim)

        hidden = self.dropout(hidden[-1, :, :])
        # hidden: (batch_size, hidden_dim)
        
        return hidden

# %%
class Decoder(nn.Module):
    def __init__(self, embedding, speakervocab_size, speaker_dim, output_dim, hidden_dim=64, dropout=0.5):
        super().__init__()

        self.embedding_dim = 100
        self.embedding = embedding
        self.hidden_dim = hidden_dim
        self.speaker_dim = speaker_dim
        self.speaker = nn.Embedding(speakervocab_size, speaker_dim)
        self.gru = nn.GRU(self.embedding_dim + speaker_dim, hidden_dim, num_layers=1, dropout=0)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, words, lst_hidden, speaker):
        # words : (1, batch_size)
        # lst_hidden: (batch_size, hidden_dim)

        embedded = self.dropout(self.embedding(words))
        # embedded : (1, batch_size, embedding_dim)
        speaker_embedded = self.speaker(speaker).view(1, -1, self.speaker_dim)
        # speaker_embedded : (1, batch_size, speaker_dim)
        embedded = torch.cat((embedded, speaker_embedded), dim=2)
        # embedded : (1, batch_size, embedding_dim + speaker_dim)
        lst_hidden = lst_hidden.view(1, -1, self.hidden_dim)
        # lst_hidden : (1, batch_size, hidden_dim)
        output, hidden = self.gru(embedded, lst_hidden)
        # output: (1, batch_size, hidden_dim)
        # hidden: (1, batch_size, hidden_dim)

        hidden = self.dropout(hidden[-1, :, :])
        # hidden: (batch_size, hidden_dim)

        pred = self.fc(hidden)
        # result: (batch_size, output_dim)
        return hidden, pred

# %%
hidden_size = 64
embed = StaticEmbedding(vocab, model_dir_or_name='en-glove-6b-100d', lower=True)
encoder = Encoder(len(vocab), embed, hidden_size, 0)
decoder = Decoder(embed, len(speaker_vocab), 100, len(vocab), hidden_size, 0)
print(encoder)
print(decoder)
# Out:
# All word in the vocab have been lowered. There are 726 words, 654 unique lowered words.
# Found 636 out of 654 words in the pre-training embedding.
# Encoder(
#   (embedding): StaticEmbedding(
#     (dropout_layer): Dropout(p=0)
#     (embedding): Embedding(642, 100, padding_idx=0)
#   )
#   (gru): GRU(100, 64)
#   (dropout): Dropout(p=0)
# )
# Decoder(
#   (embedding): StaticEmbedding(
#     (dropout_layer): Dropout(p=0)
#     (embedding): Embedding(642, 100, padding_idx=0)
#   )
#   (speaker): Embedding(51, 100)
#   (gru): GRU(200, 64)
#   (fc): Linear(in_features=64, out_features=726, bias=True)
#   (dropout): Dropout(p=0)
# )

# %%
def adjust_learning_rate(optimizer):
    """Sets the learning rate to the initial LR decayed by 10 every X epochs"""
    for param_group in optimizer.param_groups:
        param_group['lr'] *= 0.1

# %%
def Test(dev):
    batch = DataSetIter(batch_size=32, dataset=dev, sampler=SequentialSampler())
    PAD_token = 0
    EOS_token = vocab.to_index('<EOS>')
    per_list = []
    for batch_x, batch_y in batch:
        batch_size = batch_x['input_sent'].size(0)
        #print(batch_x)
        decoder_hidden = encoder(batch_x['input_sent'], batch_x['seq_len'])
        decoder_input = torch.LongTensor([[EOS_token for _ in range(batch_size)]])
        max_target_len = max([len(x) for x in batch_y['output_sent']])
        per = torch.zeros((batch_size))
        for t in range(max_target_len):
            decoder_hidden, decoder_output = decoder(
                decoder_input, decoder_hidden, batch_x['speakers']
            )
            #print(decoder_output.size())
            _, topi = decoder_output.topk(1) # [64, 1]
            pred = F.softmax(decoder_output)
            #decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = batch_y['output_sent'][:, t].view(1, -1)
            pred[:, PAD_token] = torch.ones((batch_size))
            pred = torch.gather(pred, 1, batch_y['output_sent'][:, t:t+1]).squeeze()
            per -= torch.log(pred)
            #print(decoder_input)
            #print(batch_y['output_sent'][:, t])
        #print(per, batch_x['seq_len'].float())
        per /= batch_x['seq_len'].float()
        per_list.append(sum(per))
    #print(per_list)
    return sum(per_list)/dev.get_length()

# %%
def Train(epoch, batch_size, decoder, encoder, data_bundle):
    encoder_optimizer = torch.optim.RMSprop(encoder.parameters(), lr=0.0001)
    decoder_optimizer = torch.optim.RMSprop(decoder.parameters(), lr=0.0001 * 5)
    sampler = BucketSampler(batch_size=batch_size, seq_len_field_name='seq_len')
    batch = DataSetIter(batch_size=batch_size, dataset=data_bundle.get_dataset('train'), sampler=sampler)
    
    PAD_token = 0
    EOS_token = vocab.to_index('<EOS>')
    
    start_time = time.time()
    print("-"*5+"start training"+"-"*5)
    best_res = 100 
    for i in range(epoch):
        if i % 200 == 199:
            adjust_learning_rate(encoder_optimizer)
            adjust_learning_rate(decoder_optimizer)
        loss_list = []
        for batch_x, batch_y in batch: # tqdm(batch):
            encoder_optimizer.zero_grad()
            decoder_optimizer.zero_grad()
            decoder_hidden = encoder(batch_x['input_sent'], batch_x['seq_len'])
            decoder_input = torch.LongTensor([[EOS_token for _ in range(batch_x['input_sent'].size(0))]])
            loss = 0
            max_target_len = max([len(x) for x in batch_y['output_sent']])
            pred_sent = [[] for _ in range(batch_x['input_sent'].size(0))]
            ground_truth = [[] for _ in range(batch_x['input_sent'].size(0))]
            
            use_teacher_forcing = True
            for t in range(max_target_len):
                decoder_hidden, decoder_output = decoder(
                    decoder_input, decoder_hidden, batch_x['speakers']
                )
                _, topi = decoder_output.topk(1) # [64, 1]
                if use_teacher_forcing:
                    decoder_input = batch_y['output_sent'][:, t].view(1, -1) # Next input is current target                        
                else:
                    decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_x['input_sent'].size(0))]])
                pred = F.softmax(decoder_output)
                for j in range(batch_x['input_sent'].size(0)):
                    pred_sent[j].append((topi[j][0].item()))#, pred[j, topi[j][0]].item()))
                    ground_truth[j].append((batch_y['output_sent'][j, t].item()))#, pred[j, batch_y['output_sent'][i, t].item()].item()))
                #print(batch_y['output_sent'][:, t])
                #print(loss)
                loss += F.cross_entropy(decoder_output, batch_y['output_sent'][:, t], ignore_index=PAD_token)
            
            #print('mine ', pred_sent)
            #print('truth ', ground_truth)
            loss.backward()
            encoder_optimizer.step()
            decoder_optimizer.step()
            loss_list.append(loss.item())

        res = Test(data_bundle.get_dataset('dev'))

        print('Epoch {:d} Avg Loss: {:.2f}'.format(i, sum(loss_list) / len(loss_list)), end=" ")
        print("Perplexity on Development set: {:.4f}".format(res), end=" ")
        print('{:d}ms'.format(round((time.time()-start_time)*1000)))
        
        if res < best_res:
            print('Saving')
            torch.save(embed.state_dict(), './trained_model/embed.pkl')
            torch.save(encoder.state_dict(), './trained_model/encoder.pkl')
            torch.save(decoder.state_dict(), './trained_model/decoder.pkl')
            print('Model Saved')
            # best_res = res
        
        loss_list.clear()

# %%
Train(300, 4, decoder, encoder, data_bundle)
# Out:
# -----start training-----
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch 0 Avg Loss: 156.99 Perplexity on Development set: 9.4556 517ms
# Saving
# Model Saved
# Epoch 1 Avg Loss: 142.83 Perplexity on Development set: 9.1644 990ms
# Saving
# Model Saved
# Epoch 2 Avg Loss: 131.02 Perplexity on Development set: 8.8928 1433ms
# Saving
# Model Saved
# Epoch 3 Avg Loss: 121.90 Perplexity on Development set: 8.7000 1862ms
# Saving
# Model Saved
# Epoch 4 Avg Loss: 115.59 Perplexity on Development set: 8.5817 2305ms
# Saving
# Model Saved
# Epoch 5 Avg Loss: 111.16 Perplexity on Development set: 8.5077 2764ms
# Saving
# Model Saved
# Epoch 6 Avg Loss: 107.86 Perplexity on Development set: 8.4690 3222ms
# Saving
# Model Saved
# Epoch 7 Avg Loss: 105.20 Perplexity on Development set: 8.4454 3678ms
# Saving
# Model Saved
# Epoch 8 Avg Loss: 102.93 Perplexity on Development set: 8.4339 4099ms
# Saving
# Model Saved
# Epoch 9 Avg Loss: 100.90 Perplexity on Development set: 8.4239 4511ms
# Saving
# Model Saved
# Epoch 10 Avg Loss: 99.07 Perplexity on Development set: 8.4211 4921ms
# Saving
# Model Saved
# Epoch 11 Avg Loss: 97.35 Perplexity on Development set: 8.4166 5332ms
# Saving
# Model Saved
# Epoch 12 Avg Loss: 95.72 Perplexity on Development set: 8.4174 5745ms
# Saving
# Model Saved
# Epoch 13 Avg Loss: 94.15 Perplexity on Development set: 8.4153 6217ms
# Saving
# Model Saved
# Epoch 14 Avg Loss: 92.69 Perplexity on Development set: 8.4154 6642ms
# Saving
# Model Saved
# Epoch 15 Avg Loss: 91.26 Perplexity on Development set: 8.4135 7058ms
# Saving
# Model Saved
# Epoch 16 Avg Loss: 89.84 Perplexity on Development set: 8.4141 7486ms
# Saving
# Model Saved
# Epoch 17 Avg Loss: 88.47 Perplexity on Development set: 8.4158 7905ms
# Saving
# Model Saved
# Epoch 18 Avg Loss: 87.11 Perplexity on Development set: 8.4171 8331ms
# Saving
# Model Saved
# Epoch 19 Avg Loss: 85.77 Perplexity on Development set: 8.4174 8790ms
# Saving
# Model Saved
# Epoch 20 Avg Loss: 84.46 Perplexity on Development set: 8.4229 9209ms
# Saving
# Model Saved
# Epoch 21 Avg Loss: 83.16 Perplexity on Development set: 8.4209 9676ms
# Saving
# Model Saved
# Epoch 22 Avg Loss: 81.85 Perplexity on Development set: 8.4273 10087ms
# Saving
# Model Saved
# Epoch 23 Avg Loss: 80.62 Perplexity on Development set: 8.4261 10496ms
# Saving
# Model Saved
# Epoch 24 Avg Loss: 79.39 Perplexity on Development set: 8.4346 10903ms
# Saving
# Model Saved
# Epoch 25 Avg Loss: 78.15 Perplexity on Development set: 8.4311 11305ms
# Saving
# Model Saved
# Epoch 26 Avg Loss: 76.95 Perplexity on Development set: 8.4479 11712ms
# Saving
# Model Saved
# Epoch 27 Avg Loss: 75.75 Perplexity on Development set: 8.4402 12127ms
# Saving
# Model Saved
# Epoch 28 Avg Loss: 74.59 Perplexity on Development set: 8.4559 12525ms
# Saving
# Model Saved
# Epoch 29 Avg Loss: 73.40 Perplexity on Development set: 8.4560 12925ms
# Saving
# Model Saved
# Epoch 30 Avg Loss: 72.25 Perplexity on Development set: 8.4731 13338ms
# Saving
# Model Saved
# Epoch 31 Avg Loss: 71.09 Perplexity on Development set: 8.4794 13757ms
# Saving
# Model Saved
# Epoch 32 Avg Loss: 69.95 Perplexity on Development set: 8.4864 14145ms
# Saving
# Model Saved
# Epoch 33 Avg Loss: 68.86 Perplexity on Development set: 8.5156 14538ms
# Saving
# Model Saved
# Epoch 34 Avg Loss: 67.77 Perplexity on Development set: 8.5016 14948ms
# Saving
# Model Saved
# Epoch 35 Avg Loss: 66.69 Perplexity on Development set: 8.5354 15332ms
# Saving
# Model Saved
# Epoch 36 Avg Loss: 65.70 Perplexity on Development set: 8.5341 15720ms
# Saving
# Model Saved
# Epoch 37 Avg Loss: 64.72 Perplexity on Development set: 8.5578 16092ms
# Saving
# Model Saved
# Epoch 38 Avg Loss: 63.71 Perplexity on Development set: 8.5595 16491ms
# Saving
# Model Saved
# Epoch 39 Avg Loss: 62.60 Perplexity on Development set: 8.5734 16922ms
# Saving
# Model Saved
# Epoch 40 Avg Loss: 61.59 Perplexity on Development set: 8.6064 17336ms
# Saving
# Model Saved
# Epoch 41 Avg Loss: 60.58 Perplexity on Development set: 8.6045 17753ms
# Saving
# Model Saved
# Epoch 42 Avg Loss: 59.61 Perplexity on Development set: 8.6181 18143ms
# Saving
# Model Saved
# Epoch 43 Avg Loss: 58.68 Perplexity on Development set: 8.6304 18564ms
# Saving
# Model Saved
# Epoch 44 Avg Loss: 57.80 Perplexity on Development set: 8.6593 18944ms
# Saving
# Model Saved
# Epoch 45 Avg Loss: 56.89 Perplexity on Development set: 8.6583 19342ms
# Saving
# Model Saved
# Epoch 46 Avg Loss: 55.99 Perplexity on Development set: 8.6787 19739ms
# Saving
# Model Saved
# Epoch 47 Avg Loss: 55.14 Perplexity on Development set: 8.7046 20210ms
# Saving
# Model Saved
# Epoch 48 Avg Loss: 54.27 Perplexity on Development set: 8.7046 20596ms
# Saving
# Model Saved
# Epoch 49 Avg Loss: 53.36 Perplexity on Development set: 8.7375 20999ms
# Saving
# Model Saved
# Epoch 50 Avg Loss: 52.50 Perplexity on Development set: 8.7247 21399ms
# Saving
# Model Saved
# Epoch 51 Avg Loss: 51.65 Perplexity on Development set: 8.7801 21777ms
# Saving
# Model Saved
# Epoch 52 Avg Loss: 50.84 Perplexity on Development set: 8.7438 22163ms
# Saving
# Model Saved
# Epoch 53 Avg Loss: 49.97 Perplexity on Development set: 8.7946 22543ms
# Saving
# Model Saved
# Epoch 54 Avg Loss: 49.16 Perplexity on Development set: 8.7759 22941ms
# Saving
# Model Saved
# Epoch 55 Avg Loss: 48.34 Perplexity on Development set: 8.8016 23327ms
# Saving
# Model Saved
# Epoch 56 Avg Loss: 47.56 Perplexity on Development set: 8.8106 23739ms
# Saving
# Model Saved
# Epoch 57 Avg Loss: 46.77 Perplexity on Development set: 8.8497 24171ms
# Saving
# Model Saved
# Epoch 58 Avg Loss: 45.99 Perplexity on Development set: 8.8406 24639ms
# Saving
# Model Saved
# Epoch 59 Avg Loss: 45.20 Perplexity on Development set: 8.8626 25034ms
# Saving
# Model Saved
# Epoch 60 Avg Loss: 44.50 Perplexity on Development set: 8.8700 25429ms
# Saving
# Model Saved
# Epoch 61 Avg Loss: 43.78 Perplexity on Development set: 8.8628 25816ms
# Saving
# Model Saved
# Epoch 62 Avg Loss: 43.05 Perplexity on Development set: 8.9444 26204ms
# Saving
# Model Saved
# Epoch 63 Avg Loss: 42.36 Perplexity on Development set: 8.8951 26605ms
# Saving
# Model Saved
# Epoch 64 Avg Loss: 41.61 Perplexity on Development set: 8.9383 26999ms
# Saving
# Model Saved
# Epoch 65 Avg Loss: 40.91 Perplexity on Development set: 8.9478 27390ms
# Saving
# Model Saved
# Epoch 66 Avg Loss: 40.15 Perplexity on Development set: 8.9535 27786ms
# Saving
# Model Saved
# Epoch 67 Avg Loss: 39.48 Perplexity on Development set: 8.9632 28215ms
# Saving
# Model Saved
# Epoch 68 Avg Loss: 38.80 Perplexity on Development set: 8.9924 28600ms
# Saving
# Model Saved
# Epoch 69 Avg Loss: 38.14 Perplexity on Development set: 8.9947 28970ms
# Saving
# Model Saved
# Epoch 70 Avg Loss: 37.48 Perplexity on Development set: 9.0416 29362ms
# Saving
# Model Saved
# Epoch 71 Avg Loss: 36.87 Perplexity on Development set: 8.9880 29751ms
# Saving
# Model Saved
# Epoch 72 Avg Loss: 36.21 Perplexity on Development set: 9.0971 30138ms
# Saving
# Model Saved
# Epoch 73 Avg Loss: 35.60 Perplexity on Development set: 9.0122 30544ms
# Saving
# Model Saved
# Epoch 74 Avg Loss: 34.90 Perplexity on Development set: 9.0883 30942ms
# Saving
# Model Saved
# Epoch 75 Avg Loss: 34.26 Perplexity on Development set: 9.0516 31370ms
# Saving
# Model Saved
# Epoch 76 Avg Loss: 33.60 Perplexity on Development set: 9.1221 31763ms
# Saving
# Model Saved
# Epoch 77 Avg Loss: 33.01 Perplexity on Development set: 9.0719 32146ms
# Saving
# Model Saved
# Epoch 78 Avg Loss: 32.38 Perplexity on Development set: 9.1586 32559ms
# Saving
# Model Saved
# Epoch 79 Avg Loss: 31.79 Perplexity on Development set: 9.1121 32950ms
# Saving
# Model Saved
# Epoch 80 Avg Loss: 31.21 Perplexity on Development set: 9.1908 33335ms
# Saving
# Model Saved
# Epoch 81 Avg Loss: 30.63 Perplexity on Development set: 9.1541 33735ms
# Saving
# Model Saved
# Epoch 82 Avg Loss: 30.06 Perplexity on Development set: 9.2154 34153ms
# Saving
# Model Saved
# Epoch 83 Avg Loss: 29.50 Perplexity on Development set: 9.1956 34560ms
# Saving
# Model Saved
# Epoch 84 Avg Loss: 28.93 Perplexity on Development set: 9.2394 34960ms
# Saving
# Model Saved
# Epoch 85 Avg Loss: 28.41 Perplexity on Development set: 9.2237 35351ms
# Saving
# Model Saved
# Epoch 86 Avg Loss: 27.86 Perplexity on Development set: 9.2899 35740ms
# Saving
# Model Saved
# Epoch 87 Avg Loss: 27.34 Perplexity on Development set: 9.2604 36146ms
# Saving
# Model Saved
# Epoch 88 Avg Loss: 26.82 Perplexity on Development set: 9.3119 36562ms
# Saving
# Model Saved
# Epoch 89 Avg Loss: 26.34 Perplexity on Development set: 9.2623 36967ms
# Saving
# Model Saved
# Epoch 90 Avg Loss: 25.85 Perplexity on Development set: 9.3345 37432ms
# Saving
# Model Saved
# Epoch 91 Avg Loss: 25.41 Perplexity on Development set: 9.3416 37855ms
# Saving
# Model Saved
# Epoch 92 Avg Loss: 24.86 Perplexity on Development set: 9.3729 38254ms
# Saving
# Model Saved
# Epoch 93 Avg Loss: 24.39 Perplexity on Development set: 9.3692 38706ms
# Saving
# Model Saved
# Epoch 94 Avg Loss: 23.91 Perplexity on Development set: 9.3865 39134ms
# Saving
# Model Saved
# Epoch 95 Avg Loss: 23.43 Perplexity on Development set: 9.4030 39570ms
# Saving
# Model Saved
# Epoch 96 Avg Loss: 22.97 Perplexity on Development set: 9.4008 39986ms
# Saving
# Model Saved
# Epoch 97 Avg Loss: 22.50 Perplexity on Development set: 9.4406 40412ms
# Saving
# Model Saved
# Epoch 98 Avg Loss: 22.07 Perplexity on Development set: 9.4319 40859ms
# Saving
# Model Saved
# Epoch 99 Avg Loss: 21.64 Perplexity on Development set: 9.4548 41291ms
# Saving
# Model Saved
# Epoch 100 Avg Loss: 21.19 Perplexity on Development set: 9.4507 41720ms
# Saving
# Model Saved
# Epoch 101 Avg Loss: 20.78 Perplexity on Development set: 9.4770 42190ms
# Saving
# Model Saved
# Epoch 102 Avg Loss: 20.37 Perplexity on Development set: 9.5009 42627ms
# Saving
# Model Saved
# Epoch 103 Avg Loss: 19.97 Perplexity on Development set: 9.4799 43058ms
# Saving
# Model Saved
# Epoch 104 Avg Loss: 19.59 Perplexity on Development set: 9.5367 43490ms
# Saving
# Model Saved
# Epoch 105 Avg Loss: 19.20 Perplexity on Development set: 9.4989 43919ms
# Saving
# Model Saved
# Epoch 106 Avg Loss: 18.82 Perplexity on Development set: 9.5576 44370ms
# Saving
# Model Saved
# Epoch 107 Avg Loss: 18.45 Perplexity on Development set: 9.5260 44812ms
# Saving
# Model Saved
# Epoch 108 Avg Loss: 18.05 Perplexity on Development set: 9.5988 45259ms
# Saving
# Model Saved
# Epoch 109 Avg Loss: 17.69 Perplexity on Development set: 9.5592 45700ms
# Saving
# Model Saved
# Epoch 110 Avg Loss: 17.36 Perplexity on Development set: 9.6042 46144ms
# Saving
# Model Saved
# Epoch 111 Avg Loss: 17.02 Perplexity on Development set: 9.5866 46578ms
# Saving
# Model Saved
# Epoch 112 Avg Loss: 16.68 Perplexity on Development set: 9.6327 47018ms
# Saving
# Model Saved
# Epoch 113 Avg Loss: 16.36 Perplexity on Development set: 9.6420 47479ms
# Saving
# Model Saved
# Epoch 114 Avg Loss: 16.01 Perplexity on Development set: 9.6464 47930ms
# Saving
# Model Saved
# Epoch 115 Avg Loss: 15.69 Perplexity on Development set: 9.6630 48360ms
# Saving
# Model Saved
# Epoch 116 Avg Loss: 15.36 Perplexity on Development set: 9.6576 48852ms
# Saving
# Model Saved
# Epoch 117 Avg Loss: 15.06 Perplexity on Development set: 9.6707 49304ms
# Saving
# Model Saved
# Epoch 118 Avg Loss: 14.75 Perplexity on Development set: 9.7238 49734ms
# Saving
# Model Saved
# Epoch 119 Avg Loss: 14.46 Perplexity on Development set: 9.7002 50162ms
# Saving
# Model Saved
# Epoch 120 Avg Loss: 14.17 Perplexity on Development set: 9.7328 50587ms
# Saving
# Model Saved
# Epoch 121 Avg Loss: 13.88 Perplexity on Development set: 9.7506 51017ms
# Saving
# Model Saved
# Epoch 122 Avg Loss: 13.60 Perplexity on Development set: 9.7453 51444ms
# Saving
# Model Saved
# Epoch 123 Avg Loss: 13.32 Perplexity on Development set: 9.7698 51857ms
# Saving
# Model Saved
# Epoch 124 Avg Loss: 13.05 Perplexity on Development set: 9.8024 52243ms
# Saving
# Model Saved
# Epoch 125 Avg Loss: 12.78 Perplexity on Development set: 9.7836 52680ms
# Saving
# Model Saved
# Epoch 126 Avg Loss: 12.53 Perplexity on Development set: 9.8254 53074ms
# Saving
# Model Saved
# Epoch 127 Avg Loss: 12.27 Perplexity on Development set: 9.8085 53472ms
# Saving
# Model Saved
# Epoch 128 Avg Loss: 12.04 Perplexity on Development set: 9.8480 53865ms
# Saving
# Model Saved
# Epoch 129 Avg Loss: 11.81 Perplexity on Development set: 9.8322 54254ms
# Saving
# Model Saved
# Epoch 130 Avg Loss: 11.57 Perplexity on Development set: 9.8852 54639ms
# Saving
# Model Saved
# Epoch 131 Avg Loss: 11.33 Perplexity on Development set: 9.8729 55020ms
# Saving
# Model Saved
# Epoch 132 Avg Loss: 11.09 Perplexity on Development set: 9.9104 55404ms
# Saving
# Model Saved
# Epoch 133 Avg Loss: 10.86 Perplexity on Development set: 9.8943 55798ms
# Saving
# Model Saved
# Epoch 134 Avg Loss: 10.66 Perplexity on Development set: 9.9374 56183ms
# Saving
# Model Saved
# Epoch 135 Avg Loss: 10.45 Perplexity on Development set: 9.9368 56580ms
# Saving
# Model Saved
# Epoch 136 Avg Loss: 10.23 Perplexity on Development set: 9.9661 57008ms
# Saving
# Model Saved
# Epoch 137 Avg Loss: 10.03 Perplexity on Development set: 9.9712 57401ms
# Saving
# Model Saved
# Epoch 138 Avg Loss: 9.83 Perplexity on Development set: 9.9905 57792ms
# Saving
# Model Saved
# Epoch 139 Avg Loss: 9.64 Perplexity on Development set: 10.0016 58177ms
# Saving
# Model Saved
# Epoch 140 Avg Loss: 9.44 Perplexity on Development set: 10.0121 58563ms
# Saving
# Model Saved
# Epoch 141 Avg Loss: 9.23 Perplexity on Development set: 10.0256 58956ms
# Saving
# Model Saved
# Epoch 142 Avg Loss: 9.07 Perplexity on Development set: 10.0382 59331ms
# Saving
# Model Saved
# Epoch 143 Avg Loss: 8.87 Perplexity on Development set: 10.0443 59749ms
# Saving
# Model Saved
# Epoch 144 Avg Loss: 8.69 Perplexity on Development set: 10.0583 60144ms
# Saving
# Model Saved
# Epoch 145 Avg Loss: 8.53 Perplexity on Development set: 10.0787 60545ms
# Saving
# Model Saved
# Epoch 146 Avg Loss: 8.36 Perplexity on Development set: 10.0802 60931ms
# Saving
# Model Saved
# Epoch 147 Avg Loss: 8.21 Perplexity on Development set: 10.0778 61315ms
# Saving
# Model Saved
# Epoch 148 Avg Loss: 8.03 Perplexity on Development set: 10.1104 61704ms
# Saving
# Model Saved
# Epoch 149 Avg Loss: 7.90 Perplexity on Development set: 10.0885 62088ms
# Saving
# Model Saved
# Epoch 150 Avg Loss: 7.74 Perplexity on Development set: 10.1633 62492ms
# Saving
# Model Saved
# Epoch 151 Avg Loss: 7.57 Perplexity on Development set: 10.1251 62923ms
# Saving
# Model Saved
# Epoch 152 Avg Loss: 7.40 Perplexity on Development set: 10.1795 63349ms
# Saving
# Model Saved
# Epoch 153 Avg Loss: 7.25 Perplexity on Development set: 10.1584 63739ms
# Saving
# Model Saved
# Epoch 154 Avg Loss: 7.12 Perplexity on Development set: 10.1922 64119ms
# Saving
# Model Saved
# Epoch 155 Avg Loss: 6.98 Perplexity on Development set: 10.1855 64510ms
# Saving
# Model Saved
# Epoch 156 Avg Loss: 6.83 Perplexity on Development set: 10.1977 64889ms
# Saving
# Model Saved
# Epoch 157 Avg Loss: 6.72 Perplexity on Development set: 10.2058 65291ms
# Saving
# Model Saved
# Epoch 158 Avg Loss: 6.59 Perplexity on Development set: 10.2241 65700ms
# Saving
# Model Saved
# Epoch 159 Avg Loss: 6.43 Perplexity on Development set: 10.2186 66096ms
# Saving
# Model Saved
# Epoch 160 Avg Loss: 6.32 Perplexity on Development set: 10.2515 66473ms
# Saving
# Model Saved
# Epoch 161 Avg Loss: 6.20 Perplexity on Development set: 10.2340 66853ms
# Saving
# Model Saved
# Epoch 162 Avg Loss: 6.08 Perplexity on Development set: 10.2785 67233ms
# Saving
# Model Saved
# Epoch 163 Avg Loss: 5.97 Perplexity on Development set: 10.2435 67617ms
# Saving
# Model Saved
# Epoch 164 Avg Loss: 5.87 Perplexity on Development set: 10.2852 67992ms
# Saving
# Model Saved
# Epoch 165 Avg Loss: 5.76 Perplexity on Development set: 10.2956 68397ms
# Saving
# Model Saved
# Epoch 166 Avg Loss: 5.60 Perplexity on Development set: 10.2878 68785ms
# Saving
# Model Saved
# Epoch 167 Avg Loss: 5.50 Perplexity on Development set: 10.3256 69207ms
# Saving
# Model Saved
# Epoch 168 Avg Loss: 5.40 Perplexity on Development set: 10.2927 69587ms
# Saving
# Model Saved
# Epoch 169 Avg Loss: 5.27 Perplexity on Development set: 10.3331 69976ms
# Saving
# Model Saved
# Epoch 170 Avg Loss: 5.19 Perplexity on Development set: 10.3141 70353ms
# Saving
# Model Saved
# Epoch 171 Avg Loss: 5.08 Perplexity on Development set: 10.3351 70742ms
# Saving
# Model Saved
# Epoch 172 Avg Loss: 5.01 Perplexity on Development set: 10.3862 71153ms
# Saving
# Model Saved
# Epoch 173 Avg Loss: 4.89 Perplexity on Development set: 10.3422 71611ms
# Saving
# Model Saved
# Epoch 174 Avg Loss: 4.77 Perplexity on Development set: 10.4011 72003ms
# Saving
# Model Saved
# Epoch 175 Avg Loss: 4.71 Perplexity on Development set: 10.3756 72388ms
# Saving
# Model Saved
# Epoch 176 Avg Loss: 4.59 Perplexity on Development set: 10.3998 72783ms
# Saving
# Model Saved
# Epoch 177 Avg Loss: 4.49 Perplexity on Development set: 10.4106 73165ms
# Saving
# Model Saved
# Epoch 178 Avg Loss: 4.39 Perplexity on Development set: 10.4163 73562ms
# Saving
# Model Saved
# Epoch 179 Avg Loss: 4.33 Perplexity on Development set: 10.4272 73938ms
# Saving
# Model Saved
# Epoch 180 Avg Loss: 4.23 Perplexity on Development set: 10.4348 74326ms
# Saving
# Model Saved
# Epoch 181 Avg Loss: 4.16 Perplexity on Development set: 10.4324 74708ms
# Saving
# Model Saved
# Epoch 182 Avg Loss: 4.10 Perplexity on Development set: 10.5135 75103ms
# Saving
# Model Saved
# Epoch 183 Avg Loss: 4.00 Perplexity on Development set: 10.4308 75521ms
# Saving
# Model Saved
# Epoch 184 Avg Loss: 3.91 Perplexity on Development set: 10.5058 75898ms
# Saving
# Model Saved
# Epoch 185 Avg Loss: 3.87 Perplexity on Development set: 10.4891 76280ms
# Saving
# Model Saved
# Epoch 186 Avg Loss: 3.77 Perplexity on Development set: 10.5130 76661ms
# Saving
# Model Saved
# Epoch 187 Avg Loss: 3.69 Perplexity on Development set: 10.5232 77048ms
# Saving
# Model Saved
# Epoch 188 Avg Loss: 3.62 Perplexity on Development set: 10.5357 77422ms
# Saving
# Model Saved
# Epoch 189 Avg Loss: 3.56 Perplexity on Development set: 10.5249 77813ms
# Saving
# Model Saved
# Epoch 190 Avg Loss: 3.48 Perplexity on Development set: 10.5772 78219ms
# Saving
# Model Saved
# Epoch 191 Avg Loss: 3.43 Perplexity on Development set: 10.5380 78618ms
# Saving
# Model Saved
# Epoch 192 Avg Loss: 3.34 Perplexity on Development set: 10.5530 78995ms
# Saving
# Model Saved
# Epoch 193 Avg Loss: 3.28 Perplexity on Development set: 10.5934 79428ms
# Saving
# Model Saved
# Epoch 194 Avg Loss: 3.22 Perplexity on Development set: 10.6013 79849ms
# Saving
# Model Saved
# Epoch 195 Avg Loss: 3.14 Perplexity on Development set: 10.5666 80239ms
# Saving
# Model Saved
# Epoch 196 Avg Loss: 3.11 Perplexity on Development set: 10.6085 80623ms
# Saving
# Model Saved
# Epoch 197 Avg Loss: 3.04 Perplexity on Development set: 10.5785 80996ms
# Saving
# Model Saved
# Epoch 198 Avg Loss: 2.99 Perplexity on Development set: 10.6525 81440ms
# Saving
# Model Saved
# Epoch 199 Avg Loss: 2.91 Perplexity on Development set: 10.6490 81837ms
# Saving
# Model Saved
# Epoch 200 Avg Loss: 2.93 Perplexity on Development set: 10.6462 82217ms
# Saving
# Model Saved
# Epoch 201 Avg Loss: 2.90 Perplexity on Development set: 10.6442 82611ms
# Saving
# Model Saved
# Epoch 202 Avg Loss: 2.91 Perplexity on Development set: 10.6432 82988ms
# Saving
# Model Saved
# Epoch 203 Avg Loss: 2.88 Perplexity on Development set: 10.6427 83372ms
# Saving
# Model Saved
# Epoch 204 Avg Loss: 2.90 Perplexity on Development set: 10.6430 83762ms
# Saving
# Model Saved
# Epoch 205 Avg Loss: 2.86 Perplexity on Development set: 10.6434 84142ms
# Saving
# Model Saved
# Epoch 206 Avg Loss: 2.87 Perplexity on Development set: 10.6437 84531ms
# Saving
# Model Saved
# Epoch 207 Avg Loss: 2.84 Perplexity on Development set: 10.6442 84911ms
# Saving
# Model Saved
# Epoch 208 Avg Loss: 2.84 Perplexity on Development set: 10.6449 85329ms
# Saving
# Model Saved
# Epoch 209 Avg Loss: 2.83 Perplexity on Development set: 10.6455 85714ms
# Saving
# Model Saved
# Epoch 210 Avg Loss: 2.82 Perplexity on Development set: 10.6470 86133ms
# Saving
# Model Saved
# Epoch 211 Avg Loss: 2.82 Perplexity on Development set: 10.6481 86515ms
# Saving
# Model Saved
# Epoch 212 Avg Loss: 2.83 Perplexity on Development set: 10.6496 86902ms
# Saving
# Model Saved
# Epoch 213 Avg Loss: 2.80 Perplexity on Development set: 10.6510 87284ms
# Saving
# Model Saved
# Epoch 214 Avg Loss: 2.81 Perplexity on Development set: 10.6526 87691ms
# Saving
# Model Saved
# Epoch 215 Avg Loss: 2.83 Perplexity on Development set: 10.6548 88063ms
# Saving
# Model Saved
# Epoch 216 Avg Loss: 2.80 Perplexity on Development set: 10.6569 88447ms
# Saving
# Model Saved
# Epoch 217 Avg Loss: 2.79 Perplexity on Development set: 10.6588 88828ms
# Saving
# Model Saved
# Epoch 218 Avg Loss: 2.78 Perplexity on Development set: 10.6604 89221ms
# Saving
# Model Saved
# Epoch 219 Avg Loss: 2.76 Perplexity on Development set: 10.6622 89666ms
# Saving
# Model Saved
# Epoch 220 Avg Loss: 2.79 Perplexity on Development set: 10.6639 90082ms
# Saving
# Model Saved
# Epoch 221 Avg Loss: 2.76 Perplexity on Development set: 10.6653 90493ms
# Saving
# Model Saved
# Epoch 222 Avg Loss: 2.75 Perplexity on Development set: 10.6669 90893ms
# Saving
# Model Saved
# Epoch 223 Avg Loss: 2.75 Perplexity on Development set: 10.6697 91264ms
# Saving
# Model Saved
# Epoch 224 Avg Loss: 2.75 Perplexity on Development set: 10.6716 91653ms
# Saving
# Model Saved
# Epoch 225 Avg Loss: 2.76 Perplexity on Development set: 10.6743 92043ms
# Saving
# Model Saved
# Epoch 226 Avg Loss: 2.73 Perplexity on Development set: 10.6763 92460ms
# Saving
# Model Saved
# Epoch 227 Avg Loss: 2.71 Perplexity on Development set: 10.6778 93329ms
# Saving
# Model Saved
# Epoch 228 Avg Loss: 2.72 Perplexity on Development set: 10.6795 93692ms
# Saving
# Model Saved
# Epoch 229 Avg Loss: 2.71 Perplexity on Development set: 10.6816 94029ms
# Saving
# Model Saved
# Epoch 230 Avg Loss: 2.70 Perplexity on Development set: 10.6836 94368ms
# Saving
# Model Saved
# Epoch 231 Avg Loss: 2.68 Perplexity on Development set: 10.6845 94759ms
# Saving
# Model Saved
# Epoch 232 Avg Loss: 2.67 Perplexity on Development set: 10.6866 95173ms
# Saving
# Model Saved
# Epoch 233 Avg Loss: 2.68 Perplexity on Development set: 10.6886 95560ms
# Saving
# Model Saved
# Epoch 234 Avg Loss: 2.69 Perplexity on Development set: 10.6910 95940ms
# Saving
# Model Saved
# Epoch 235 Avg Loss: 2.66 Perplexity on Development set: 10.6927 96322ms
# Saving
# Model Saved
# Epoch 236 Avg Loss: 2.68 Perplexity on Development set: 10.6946 96749ms
# Saving
# Model Saved
# Epoch 237 Avg Loss: 2.64 Perplexity on Development set: 10.6973 97145ms
# Saving
# Model Saved
# Epoch 238 Avg Loss: 2.64 Perplexity on Development set: 10.7000 97530ms
# Saving
# Model Saved
# Epoch 239 Avg Loss: 2.63 Perplexity on Development set: 10.7017 97913ms
# Saving
# Model Saved
# Epoch 240 Avg Loss: 2.62 Perplexity on Development set: 10.7032 98299ms
# Saving
# Model Saved
# Epoch 241 Avg Loss: 2.62 Perplexity on Development set: 10.7052 98693ms
# Saving
# Model Saved
# Epoch 242 Avg Loss: 2.64 Perplexity on Development set: 10.7075 99093ms
# Saving
# Model Saved
# Epoch 243 Avg Loss: 2.60 Perplexity on Development set: 10.7098 99506ms
# Saving
# Model Saved
# Epoch 244 Avg Loss: 2.59 Perplexity on Development set: 10.7115 99896ms
# Saving
# Model Saved
# Epoch 245 Avg Loss: 2.58 Perplexity on Development set: 10.7140 100281ms
# Saving
# Model Saved
# Epoch 246 Avg Loss: 2.59 Perplexity on Development set: 10.7164 100690ms
# Saving
# Model Saved
# Epoch 247 Avg Loss: 2.58 Perplexity on Development set: 10.7193 101072ms
# Saving
# Model Saved
# Epoch 248 Avg Loss: 2.59 Perplexity on Development set: 10.7210 101456ms
# Saving
# Model Saved
# Epoch 249 Avg Loss: 2.59 Perplexity on Development set: 10.7228 101858ms
# Saving
# Model Saved
# Epoch 250 Avg Loss: 2.56 Perplexity on Development set: 10.7259 102256ms
# Saving
# Model Saved
# Epoch 251 Avg Loss: 2.55 Perplexity on Development set: 10.7284 102703ms
# Saving
# Model Saved
# Epoch 252 Avg Loss: 2.55 Perplexity on Development set: 10.7312 103094ms
# Saving
# Model Saved
# Epoch 253 Avg Loss: 2.53 Perplexity on Development set: 10.7332 103478ms
# Saving
# Model Saved
# Epoch 254 Avg Loss: 2.52 Perplexity on Development set: 10.7352 103878ms
# Saving
# Model Saved
# Epoch 255 Avg Loss: 2.52 Perplexity on Development set: 10.7367 104275ms
# Saving
# Model Saved
# Epoch 256 Avg Loss: 2.54 Perplexity on Development set: 10.7397 104658ms
# Saving
# Model Saved
# Epoch 257 Avg Loss: 2.49 Perplexity on Development set: 10.7416 105052ms
# Saving
# Model Saved
# Epoch 258 Avg Loss: 2.48 Perplexity on Development set: 10.7426 105466ms
# Saving
# Model Saved
# Epoch 259 Avg Loss: 2.49 Perplexity on Development set: 10.7459 106086ms
# Saving
# Model Saved
# Epoch 260 Avg Loss: 2.48 Perplexity on Development set: 10.7491 106644ms
# Saving
# Model Saved
# Epoch 261 Avg Loss: 2.50 Perplexity on Development set: 10.7504 107099ms
# Saving
# Model Saved
# Epoch 262 Avg Loss: 2.47 Perplexity on Development set: 10.7536 107622ms
# Saving
# Model Saved
# Epoch 263 Avg Loss: 2.46 Perplexity on Development set: 10.7564 108084ms
# Saving
# Model Saved
# Epoch 264 Avg Loss: 2.44 Perplexity on Development set: 10.7586 108521ms
# Saving
# Model Saved
# Epoch 265 Avg Loss: 2.44 Perplexity on Development set: 10.7602 109000ms
# Saving
# Model Saved
# Epoch 266 Avg Loss: 2.44 Perplexity on Development set: 10.7619 109483ms
# Saving
# Model Saved
# Epoch 267 Avg Loss: 2.43 Perplexity on Development set: 10.7643 110002ms
# Saving
# Model Saved
# Epoch 268 Avg Loss: 2.43 Perplexity on Development set: 10.7687 110487ms
# Saving
# Model Saved
# Epoch 269 Avg Loss: 2.40 Perplexity on Development set: 10.7708 110939ms
# Saving
# Model Saved
# Epoch 270 Avg Loss: 2.40 Perplexity on Development set: 10.7743 111439ms
# Saving
# Model Saved
# Epoch 271 Avg Loss: 2.40 Perplexity on Development set: 10.7755 111999ms
# Saving
# Model Saved
# Epoch 272 Avg Loss: 2.39 Perplexity on Development set: 10.7783 112470ms
# Saving
# Model Saved
# Epoch 273 Avg Loss: 2.39 Perplexity on Development set: 10.7808 112930ms
# Saving
# Model Saved
# Epoch 274 Avg Loss: 2.37 Perplexity on Development set: 10.7827 113308ms
# Saving
# Model Saved
# Epoch 275 Avg Loss: 2.40 Perplexity on Development set: 10.7862 113757ms
# Saving
# Model Saved
# Epoch 276 Avg Loss: 2.36 Perplexity on Development set: 10.7879 114140ms
# Saving
# Model Saved
# Epoch 277 Avg Loss: 2.35 Perplexity on Development set: 10.7903 114585ms
# Saving
# Model Saved
# Epoch 278 Avg Loss: 2.38 Perplexity on Development set: 10.7927 114973ms
# Saving
# Model Saved
# Epoch 279 Avg Loss: 2.33 Perplexity on Development set: 10.7968 115363ms
# Saving
# Model Saved
# Epoch 280 Avg Loss: 2.34 Perplexity on Development set: 10.7972 115801ms
# Saving
# Model Saved
# Epoch 281 Avg Loss: 2.32 Perplexity on Development set: 10.8038 116211ms
# Saving
# Model Saved
# Epoch 282 Avg Loss: 2.32 Perplexity on Development set: 10.8011 116616ms
# Saving
# Model Saved
# Epoch 283 Avg Loss: 2.31 Perplexity on Development set: 10.8107 117029ms
# Saving
# Model Saved
# Epoch 284 Avg Loss: 2.33 Perplexity on Development set: 10.8089 117411ms
# Saving
# Model Saved
# Epoch 285 Avg Loss: 2.30 Perplexity on Development set: 10.8146 117801ms
# Saving
# Model Saved
# Epoch 286 Avg Loss: 2.28 Perplexity on Development set: 10.8139 118227ms
# Saving
# Model Saved
# Epoch 287 Avg Loss: 2.28 Perplexity on Development set: 10.8178 118638ms
# Saving
# Model Saved
# Epoch 288 Avg Loss: 2.27 Perplexity on Development set: 10.8205 119015ms
# Saving
# Model Saved
# Epoch 289 Avg Loss: 2.27 Perplexity on Development set: 10.8229 119392ms
# Saving
# Model Saved
# Epoch 290 Avg Loss: 2.28 Perplexity on Development set: 10.8264 119832ms
# Saving
# Model Saved
# Epoch 291 Avg Loss: 2.26 Perplexity on Development set: 10.8301 120229ms
# Saving
# Model Saved
# Epoch 292 Avg Loss: 2.25 Perplexity on Development set: 10.8297 120696ms
# Saving
# Model Saved
# Epoch 293 Avg Loss: 2.24 Perplexity on Development set: 10.8348 121118ms
# Saving
# Model Saved
# Epoch 294 Avg Loss: 2.26 Perplexity on Development set: 10.8361 121506ms
# Saving
# Model Saved
# Epoch 295 Avg Loss: 2.26 Perplexity on Development set: 10.8413 121900ms
# Saving
# Model Saved
# Epoch 296 Avg Loss: 2.22 Perplexity on Development set: 10.8435 122278ms
# Saving
# Model Saved
# Epoch 297 Avg Loss: 2.21 Perplexity on Development set: 10.8442 122665ms
# Saving
# Model Saved
# Epoch 298 Avg Loss: 2.22 Perplexity on Development set: 10.8495 123055ms
# Saving
# Model Saved
# Epoch 299 Avg Loss: 2.22 Perplexity on Development set: 10.8512 123436ms
# Saving
# Model Saved

# %%
def Pred(test):
    batch = DataSetIter(batch_size=1, dataset=test, sampler=SequentialSampler())
    EOS_token = vocab.to_index('<EOS>')
    per_list = []
    for batch_x, batch_y in batch:
        decoder_hidden = encoder(batch_x['input_sent'], batch_x['seq_len'])
        decoder_input = torch.LongTensor([[EOS_token]])
        per = 0
        pred = []
        for t in range(20):
            decoder_hidden, decoder_output = decoder(
                decoder_input, decoder_hidden, batch_x['speakers']
            )
            _, topi = decoder_output.topk(1) # [64, 1]
            decoder_input = torch.LongTensor([[topi[0][0]]])
            pred.append(decoder_input[0, 0].item())
            if decoder_input[0, 0].item() == vocab.to_index('<EOS>'): break
        print(" ".join([vocab.to_word(x.item()) for x in list(batch_x['input_sent'][0, :])]))
        print(movie_characters[speaker_vocab.to_word(batch_x['speakers'].item())]['character name'] + " says: " + " ".join([vocab.to_word(x) for x in pred]))
        print(" ".join([vocab.to_word(x.item()) for x in list(batch_y['output_sent'][0, :])]))
        print()

# %%
embed.load_state_dict(torch.load('./trained_model/embed.pkl'))
encoder.load_state_dict(torch.load('./trained_model/encoder.pkl'))
decoder.load_state_dict(torch.load('./trained_model/decoder.pkl'))
Pred(train[:10])
# Out:
# Elaine , I 'm going back there . Just hold onto that stick and try to control this hunk of tin as best you can .
# TED says: Ted , please be careful . <EOS>
# Ted , please be careful . <EOS>
#
# You 've got Penthouse , Playboy , Hustler , etc . Nobody even considers them pornography anymore . Then , there 's mainstream hardcore . Triple X . The difference is penetration . That 's hardcore . That whole industry 's up in the valley . Writers , directors , porn stars . They 're celebrities , or they think they are . They pump out 150 videos a week . A week . They 've even got a porno Academy Awards . America loves pornography . Anybody tells you they never use pornography , they 're lying . Somebody 's buying those videos . Somebody 's out there spending 900 million dollars a year on phone sex . Know what else ? It 's only gon na get worse . More and more you 'll see perverse hardcore coming into the mainstream , because that 's evolution . Desensitization . Oh my God , Elvis Presley 's wiggling his hips , how offensive ! Nowadays , Mtv 's showing girls dancing around in thong bikinis with their asses hanging out . Know what I mean ? For the porn-addict , big tits are n't big enough after a while . They have to be the biggest tits ever . Some porn chicks are putting in breast implants bigger than your head , literally . Soon , Playboy is gon na be Penthouse , Penthouse 'll be Hustler , Hustler 'll be hardcore , and hardcore films 'll be medical films . People 'll be jerking off to women laying around with open wounds . There 's nowhere else for it to go .
# WELLES says: Interesting theory . <EOS>
# Interesting theory . <EOS>
#
# Where are your parents ?
# WELLES says: I do n't know , where are yours ? <EOS>
# I do n't know , where are yours ? <EOS>
#
# Why do girls like that always like guys like that ?
# MICHAEL says: Because they 're bred to . Their mothers liked guys like that , and their grandmothers before them . Their
# Because they 're bred to . Their mothers liked guys like that , and their grandmothers before them . Their gene pool is rarely diluted . <EOS>
#
# Options .
# PRESIDENT says: Wait or act . <EOS>
# Wait or act . <EOS>
#
# Leeloo ... is ... she 's ...
# KORBEN says: Yes , and more than that ... You must give her the Stones , she 's the only one who
# Yes , and more than that ... You must give her the Stones , she 's the only one who knows how to use them . <EOS>
#
# Well then somebody 's just going to have to go out there . Take a portable terminal and go out there and plug in manually .
# RIPLEY says: Oh , right ! Right ! With those things running around . No way . <EOS>
# Oh , right ! Right ! With those things running around . No way . <EOS>
#
# Nothing in the fucking house to drink . Not a fucking thing . My house , my money , my truck -- stolen !
# WADE says: Got here just in time . Go ahead . Jump in line . Maybe you 'll win a prize .
# I do n't know you . My goddamn father and I do n't know you . <EOS>
#
# North , actually . How 'd you ?
# CAMERON says: I was kidding . People actually live there ? <EOS>
# I was kidding . People actually live there ? <EOS>
#
# Ca n't it wait ?
# MARSHALL says: No , Mr. President . It ca n't . <EOS>
# No , Mr. President . It ca n't . <EOS>
